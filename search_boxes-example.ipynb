# %%
import numpy as np
import search_boxes
import importlib

importlib.reload(search_boxes)
from search_boxes import workflow_demo, search_structure

# %%
workflow_demo(exp_name="cos_sim", metric="cosine")
# Out:
# Molecule 772: Similarity = 0.799123118323422
# Polar axis: [ 0.7371768   0.6726077  -0.06457082]
# Modified atoms: [770, 772, 771, 773, 774]

# %%
workflow_demo(exp_name="circ_sim_wc_4", metric="circle", weight_cutoff=4.0)
# Out:
# Molecule 42: Similarity = 0.6249050783760532
# Polar axis: [-0.26920033  0.5159668  -0.8132094 ]
# Modified atoms: [40, 42, 41, 43, 44]

# %%
workflow_demo(exp_name="circ_sim_wc_5", metric="circle", weight_cutoff=5.0)
# Out:
# Molecule 832: Similarity = 0.6096738067813803
# Polar axis: [ 0.79291826 -0.21873692 -0.56871325]
# Modified atoms: [830, 832, 831, 833, 834]

# %%
workflow_demo(exp_name="circ_sim_wc_6", metric="circle", weight_cutoff=6.0)
# Out:
# Molecule 573: Similarity = 0.5660496813119767
# Polar axis: [-0.7250872  -0.14273374  0.6737029 ]
# Modified atoms: [570, 573, 571, 572, 574]
