# %%
import numpy as np
import search_boxes
import importlib

importlib.reload(search_boxes)
from search_boxes import workflow_demo, search_structure

# %%
workflow_demo()
# Out:
# Molecule 316: Similarity = 0.4532579584267701
# Polar axis: [-0.093744    0.39151943  0.9153822 ]
