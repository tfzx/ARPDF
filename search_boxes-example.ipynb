# %%
import numpy as np
import search_boxes
import importlib

importlib.reload(search_boxes)
from search_boxes import workflow_demo, search_structure

# %%
workflow_demo()
# Out:
# 344 676
# 0.2961987392576125
# Molecule 344: Similarity = 0.2961987392576125
# Polar axis: [0.3991449  0.91568464 0.04695816]
# Modified atoms: [340, 344, 341, 342, 343]
